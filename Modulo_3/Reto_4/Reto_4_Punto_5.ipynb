# %% [markdown]
# <a href="https://colab.research.google.com/github/Felipe-DelosSantos09/Diplomado-IA/blob/master/Reto_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Es el punto 5 del reto, los demás puntos estan en la carpeta del reto 4.

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno

# %%
# %matplotlib qt

# %%
r = pd.read_csv('rama_2023_05_missing_outliers_limited.csv')
r.head()
# Out:
#         fecha        CO         NO        NO2        NOX         O3  \
# 0  2015-01-01  1.050696  22.765528  24.225155  46.987578  23.175150
# 1  2015-01-02  0.807585  32.249608  21.554160  53.800628  17.268366
# 2  2015-01-03  0.640755  21.686916  19.394081  41.071651  15.486486
# 3  2015-01-04  0.726940  24.606272  19.560976        NaN  17.329032
# 4  2015-01-05  0.530815  11.443182  20.990260  32.439935  14.470588
#
#          PM10       PM25        SO2
# 0  105.573684  78.953405  11.554723
# 1   36.687845  15.449438        NaN
# 2   29.269022  12.915129   1.436937
# 3   39.961538  16.838284   1.809061
# 4   31.855643        NaN   8.315789

# %%
r.set_index('fecha', inplace=True)

# %%
r.head()
# Out:
#                   CO         NO        NO2        NOX         O3        PM10  \
# fecha
# 2015-01-01  1.050696  22.765528  24.225155  46.987578  23.175150  105.573684
# 2015-01-02  0.807585  32.249608  21.554160  53.800628  17.268366   36.687845
# 2015-01-03  0.640755  21.686916  19.394081  41.071651  15.486486   29.269022
# 2015-01-04  0.726940  24.606272  19.560976        NaN  17.329032   39.961538
# 2015-01-05  0.530815  11.443182  20.990260  32.439935  14.470588   31.855643
#
#                  PM25        SO2
# fecha
# 2015-01-01  78.953405  11.554723
# 2015-01-02  15.449438        NaN
# 2015-01-03  12.915129   1.436937
# 2015-01-04  16.838284   1.809061
# 2015-01-05        NaN   8.315789

# %%
#plt.plot(r.index,r["NOX"])

# %%
# Función para graficar series de tiempo con rango de fechas y zonas específicas
def plot_time_series(r, variables, ylabel, title, start_date=None, end_date=None):
    # Configurar el tamaño de la figura del gráfico
    plt.figure(figsize=(15, 5))

    # Si se proporcionan fechas de inicio y fin, filtrar el DataFrame para ese rango de fechas
    if start_date and end_date:
        r = r.loc[start_date:end_date]

    # Iterar sobre cada zona especificada en la lista de zonas
    for variable in variables:
        # Crear el nombre de la columna combinando la zona y la variable
        column = f"{variable}"

        # Verificar si la columna existe en el DataFrame
        if column in r.columns:
            # Graficar la serie de tiempo de la columna
            plt.plot(r.index, r[column], label=column)
        else:
            # Imprimir un mensaje si la columna no se encuentra en el DataFrame
            print(f"Columna {column} no encontrada en el DataFrame")

    # Etiqueta del eje x
    plt.xlabel('Fecha')
    # Etiqueta del eje y
    plt.ylabel(ylabel)
    # Título del gráfico
    plt.title(title)
    # Mostrar la leyenda del gráfico
    plt.legend()
    # Mostrar el gráfico
    plt.show()

# %% [markdown]
# ## Series de tiempo

# %%
# Llamar a la función para graficar PM10 en las zonas específicas con el rango de fechas indicado
plot_time_series(r,['CO'], 'Cantidad CO', 'Series de Tiempo de CO', start_date='2015-01-01', end_date='2015-12-31')

# %%
plot_time_series(r,['NO'], 'Cantidad NO', 'Series de Tiempo de NO', start_date='2015-01-01', end_date='2015-12-31')

# %%
plot_time_series(r,['NO2'], 'Cantidad NO2', 'Series de Tiempo de NO2', start_date='2015-01-01', end_date='2015-12-31')

# %%
plot_time_series(r,['NOX'], 'Cantidad NOX', 'Series de Tiempo de NOX', start_date='2015-01-01', end_date='2015-12-31')

# %%
plot_time_series(r,['O3'], 'Cantidad O3', 'Series de Tiempo de O3', start_date='2015-01-01', end_date='2015-12-31')

# %%
plot_time_series(r,['PM10'], 'Cantidad PM10', 'Series de Tiempo de PM10', start_date='2015-01-01', end_date='2015-12-31')

# %%
plot_time_series(r,['PM25'], 'Cantidad PM25', 'Series de Tiempo de PM25', start_date='2015-01-01', end_date='2015-12-31')

# %%
plot_time_series(r,['SO2'], 'Cantidad SO2', 'Series de Tiempo de SO2', start_date='2015-01-01', end_date='2015-12-31')

# %%
#r.plot()

# %% [markdown]
# ## Valores atipicos con Diagrama de Caja y bigotes

# %%
r.boxplot(column="CO")
# Out:
# <Axes: title={'center': 'Series de Tiempo de SO2'}, xlabel='Fecha', ylabel='Cantidad SO2'>

# %%
r.boxplot(column="NO")
# Out:
# <Axes: title={'center': 'Series de Tiempo de SO2'}, xlabel='Fecha', ylabel='Cantidad SO2'>

# %%
r.boxplot(column="NO2")
# Out:
# <Axes: title={'center': 'Series de Tiempo de SO2'}, xlabel='Fecha', ylabel='Cantidad SO2'>

# %%
r.boxplot(column="NOX")
# Out:
# <Axes: title={'center': 'Series de Tiempo de SO2'}, xlabel='Fecha', ylabel='Cantidad SO2'>

# %%
r.boxplot(column="O3")
# Out:
# <Axes: title={'center': 'Series de Tiempo de SO2'}, xlabel='Fecha', ylabel='Cantidad SO2'>

# %%
r.boxplot(column="PM10")
# Out:
# <Axes: title={'center': 'Series de Tiempo de SO2'}, xlabel='Fecha', ylabel='Cantidad SO2'>

# %%
r.boxplot(column="PM25")
# Out:
# <Axes: title={'center': 'Series de Tiempo de SO2'}, xlabel='Fecha', ylabel='Cantidad SO2'>

# %%
r.boxplot(column="SO2")
# Out:
# <Axes: title={'center': 'Series de Tiempo de SO2'}, xlabel='Fecha', ylabel='Cantidad SO2'>

# %% [markdown]
# ## Manejo de datos atipicos

# %%
Q1 = r["CO"].quantile(0.25)
Q3 = r["CO"].quantile(0.75)

IQR = Q3 - Q1

limite_inferior = Q1 - 1.5 * IQR

print(limite_inferior)

limite_superior = Q3 + 1.5 * IQR

print(limite_superior)
# Out:
# -0.08089470090070511
# 1.0107079710068283

# %%
Q1 = r["NO"].quantile(0.25)
Q3 = r["NO"].quantile(0.75)

IQR = Q3 - Q1

limite_inferior = Q1 - 1.5 * IQR

print(limite_inferior)

limite_superior = Q3 + 1.5 * IQR

print(limite_superior)
# Out:
# -8.917274816874642
# 36.38480134096411

# %%
Q1 = r["NO2"].quantile(0.25)
Q3 = r["NO2"].quantile(0.75)

IQR = Q3 - Q1

limite_inferior = Q1 - 1.5 * IQR

print(limite_inferior)

limite_superior = Q3 + 1.5 * IQR

print(limite_superior)
# Out:
# 5.202670371312973
# 39.726217144190244

# %%
Q1 = r["NOX"].quantile(0.25)
Q3 = r["NOX"].quantile(0.75)

IQR = Q3 - Q1

limite_inferior = Q1 - 1.5 * IQR

print(limite_inferior)

limite_superior = Q3 + 1.5 * IQR

print(limite_superior)
# Out:
# -2.633559483117434
# 76.41228600160113

# %%
Q1 = r["O3"].quantile(0.25)
Q3 = r["O3"].quantile(0.75)

IQR = Q3 - Q1

limite_inferior = Q1 - 1.5 * IQR

print(limite_inferior)

limite_superior = Q3 + 1.5 * IQR

print(limite_superior)
# Out:
# 5.559395728944619
# 54.49971493481195

# %%
Q1 = r["PM10"].quantile(0.25)
Q3 = r["PM10"].quantile(0.75)

IQR = Q3 - Q1

limite_inferior = Q1 - 1.5 * IQR

print(limite_inferior)

limite_superior = Q3 + 1.5 * IQR

print(limite_superior)
# Out:
# -5.509170550050008
# 87.96178242687199

# %%
Q1 = r["PM25"].quantile(0.25)
Q3 = r["PM25"].quantile(0.75)

IQR = Q3 - Q1

limite_inferior = Q1 - 1.5 * IQR

print(limite_inferior)

limite_superior = Q3 + 1.5 * IQR

print(limite_superior)
# Out:
# -1.041345510192011
# 42.55665915796706

# %%
Q1 = r["SO2"].quantile(0.25)
Q3 = r["SO2"].quantile(0.75)

IQR = Q3 - Q1

limite_inferior = Q1 - 1.5 * IQR

print(limite_inferior)

limite_superior = Q3 + 1.5 * IQR

print(limite_superior)
# Out:
# -2.6786859460238768
# 8.632066083884574

# %%
CO > 1.1
NO > 36.4
NO2 > 39.73
NOX > 76.41
O3 > 60
PM10 > 107
PM25 > 42.55
SO2 > 12

# %%
r.loc[r["CO"] > 1.1, "CO"] = np.nan
r["CO"]
# Out:
# fecha
# 2015-01-01    1.050696
# 2015-01-02    0.807585
# 2015-01-03    0.640755
# 2015-01-04    0.726940
# 2015-01-05    0.530815
#                 ...
# 2023-05-27    0.256722
# 2023-05-28    0.286826
# 2023-05-29    0.482077
# 2023-05-30    0.441455
# 2023-05-31    0.340404
# Name: CO, Length: 3073, dtype: float64

# %%
r.loc[r["NO"] > 36.4, "NO"] = np.nan
r["NO"]
# Out:
# fecha
# 2015-01-01    22.765528
# 2015-01-02    32.249608
# 2015-01-03    21.686916
# 2015-01-04    24.606272
# 2015-01-05    11.443182
#                 ...
# 2023-05-27     3.750583
# 2023-05-28          NaN
# 2023-05-29    11.448113
# 2023-05-30    13.893519
# 2023-05-31     5.353066
# Name: NO, Length: 3073, dtype: float64

# %%
r.loc[r["NO2"] > 39.73, "NO2"] = np.nan
r["NO2"]
# Out:
# fecha
# 2015-01-01    24.225155
# 2015-01-02    21.554160
# 2015-01-03    19.394081
# 2015-01-04    19.560976
# 2015-01-05    20.990260
#                 ...
# 2023-05-27    17.284351
# 2023-05-28    16.349241
# 2023-05-29    24.521154
# 2023-05-30    22.615530
# 2023-05-31          NaN
# Name: NO2, Length: 3073, dtype: float64

# %%
r.loc[r["NOX"] > 76.41, "NOX"] = np.nan
r["NOX"]
# Out:
# fecha
# 2015-01-01    46.987578
# 2015-01-02    53.800628
# 2015-01-03    41.071651
# 2015-01-04          NaN
# 2015-01-05    32.439935
#                 ...
# 2023-05-27    21.629371
# 2023-05-28    20.230769
# 2023-05-29    36.436321
# 2023-05-30    37.224537
# 2023-05-31    25.710359
# Name: NOX, Length: 3073, dtype: float64

# %%
r.loc[r["O3"] > 60, "O3"] = np.nan
r["O3"]
# Out:
# fecha
# 2015-01-01    23.175150
# 2015-01-02    17.268366
# 2015-01-03    15.486486
# 2015-01-04    17.329032
# 2015-01-05    14.470588
#                 ...
# 2023-05-27    41.580645
# 2023-05-28    36.913761
# 2023-05-29    29.697068
# 2023-05-30    36.185971
# 2023-05-31          NaN
# Name: O3, Length: 3073, dtype: float64

# %%
r.loc[r["PM10"] > 107, "PM10"] = np.nan
r["PM10"]
# Out:
# fecha
# 2015-01-01    105.573684
# 2015-01-02     36.687845
# 2015-01-03     29.269022
# 2015-01-04     39.961538
# 2015-01-05     31.855643
#                  ...
# 2023-05-27           NaN
# 2023-05-28     28.580000
# 2023-05-29     30.241486
# 2023-05-30     35.859532
# 2023-05-31     42.203390
# Name: PM10, Length: 3073, dtype: float64

# %%
r.loc[r["PM25"] > 90, "PM25"] = np.nan
r["PM25"]
# Out:
# fecha
# 2015-01-01    78.953405
# 2015-01-02    15.449438
# 2015-01-03    12.915129
# 2015-01-04    16.838284
# 2015-01-05          NaN
#                 ...
# 2023-05-27    21.170139
# 2023-05-28    18.454861
# 2023-05-29    16.692857
# 2023-05-30    20.888525
# 2023-05-31    24.787097
# Name: PM25, Length: 3073, dtype: float64

# %%
r.loc[r["SO2"] > 12, "SO2"] = np.nan
r["SO2"]
# Out:
# fecha
# 2015-01-01    11.554723
# 2015-01-02          NaN
# 2015-01-03     1.436937
# 2015-01-04     1.809061
# 2015-01-05     8.315789
#                 ...
# 2023-05-27     2.735683
# 2023-05-28     2.331658
# 2023-05-29     1.071588
# 2023-05-30     1.181818
# 2023-05-31     1.402083
# Name: SO2, Length: 3073, dtype: float64

# %% [markdown]
# ### Imputación de valores nulos

# %%
r.isnull().sum()
# Out:
# CO      190
# NO      233
# NO2     214
# NOX     190
# O3      162
# PM10    152
# PM25    150
# SO2     252
# dtype: int64

# %%
msno.matrix(r)
# Out:
# <Axes: >

# %%
# Filtrar el DataFrame para obtener las columnas 'CE-CO' y 'CE-PM10' en el rango de fechas especificado
r_impute = r[['CO', 'NO', 'NO2', 'NOX', 'O3', 'PM10', 'PM25', 'SO2']].loc['2015-01-01':'2023-05-31']

# Contar y mostrar el número de valores nulos en cada columna del DataFrame filtrado
print("\nNúmero de valores nulos antes de la imputación:")
print(r_impute.isnull().sum())

# Aplicar el promedio móvil para llenar los valores nulos en el DataFrame
r_impute.loc[:, :] = r_impute.fillna(r_impute.rolling(window=12, min_periods=1).mean())

# Mostrar las primeras filas del DataFrame después de la imputación y adición de columnas
print("\nPrimeras filas del DataFrame después del promedio móvil y adición de columnas:")
print(r_impute.head())

# Contar y mostrar el número de valores nulos después del promedio móvil
print("\nNúmero de valores nulos después del promedio móvil:")
print(r_impute.isnull().sum())

# Graficar las series de tiempo de 'CE-CO' y 'CE-PM10' después del promedio móvil
plt.figure(figsize=(12, 6))
r_impute[['CO', 'NO', 'NO2', 'NOX', 'O3', 'PM10', 'PM25', 'SO2']].loc['2015-01-01':'2023-05-31'].plot(ax=plt.gca())
plt.title('Series de Tiempo de CE-CO y CE-PM10 (Después del Promedio Móvil)')
plt.xlabel('Fecha')
plt.ylabel('Concentración')
plt.show()
# Out:
# Número de valores nulos antes de la imputación:
# CO      190
# NO      233
# NO2     214
# NOX     190
# O3      162
# PM10    152
# PM25    150
# SO2     252
# dtype: int64
#
# Primeras filas del DataFrame después del promedio móvil y adición de columnas:
#                   CO         NO        NO2        NOX         O3        PM10  \
# fecha
# 2015-01-01  1.050696  22.765528  24.225155  46.987578  23.175150  105.573684
# 2015-01-02  0.807585  32.249608  21.554160  53.800628  17.268366   36.687845
# 2015-01-03  0.640755  21.686916  19.394081  41.071651  15.486486   29.269022
# 2015-01-04  0.726940  24.606272  19.560976  47.286619  17.329032   39.961538
# 2015-01-05  0.530815  11.443182  20.990260  32.439935  14.470588   31.855643
#
#                  PM25        SO2
# fecha
# 2015-01-01  78.953405  11.554723
# 2015-01-02  15.449438  11.554723
# 2015-01-03  12.915129   1.436937
# 2015-01-04  16.838284   1.809061
# 2015-01-05  31.039064   8.315789
#
# Número de valores nulos después del promedio móvil:
# CO      0
# NO      0
# NO2     0
# NOX     0
# O3      0
# PM10    0
# PM25    0
# SO2     0
# dtype: int64

# %%
r_impute.isnull().sum()
# Out:
# CO      0
# NO      0
# NO2     0
# NOX     0
# O3      0
# PM10    0
# PM25    0
# SO2     0
# dtype: int64

# %%
r_impute.describe()
# Out:
#                 CO           NO          NO2          NOX           O3  \
# count  3073.000000  3073.000000  3073.000000  3073.000000  3073.000000
# mean      0.477670    14.215250    22.740125    37.520944    30.427253
# std       0.192706     7.586843     6.063086    13.439874     8.826064
# min       0.115917     1.168000     8.061630     9.983402     3.226054
# 25%       0.326431     8.122622    18.270876    27.169118    24.009105
# 50%       0.443210    12.756623    22.421517    35.827511    29.856667
# 75%       0.598447    19.119231    26.753846    46.372320    36.077236
# max       1.099068    36.159420    39.633681    76.011594    58.091922
#
#               PM10         PM25          SO2
# count  3073.000000  3073.000000  3073.000000
# mean     41.844646    21.301206     3.267435
# std      15.686033     8.731267     2.305214
# min       8.218487     2.849315     0.630435
# 25%      29.569343    15.359801     1.588542
# 50%      40.237410    20.532578     2.534188
# 75%      52.708716    26.181818     4.208333
# max     105.573684    86.909910    11.978131

# %%
#r_impute.to_csv('Agentes_contaminantes_corregido.csv', index=False)

# %% [markdown]
# # Modelado y predicción

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, LSTM, GRU, Dense
from tensorflow.keras import backend as K

# %%
def rmse(y_true, y_pred):

    return K.sqrt(K.mean(K.square(y_pred - y_true)))


def split_dataframe(df, train_ratio=0.7, test_ratio=0.2):

    total_size = len(df)  # Tamaño total del DataFrame
    train_size = int(total_size * train_ratio)  # Tamaño del conjunto de entrenamiento
    test_size = int(total_size * test_ratio)  # Tamaño del conjunto de prueba
    eval_size = total_size - train_size - test_size  # Tamaño del conjunto de evaluación

    df_train = df.iloc[:train_size]  # Conjunto de entrenamiento
    df_test = df.iloc[train_size:train_size + test_size]  # Conjunto de prueba
    df_eval = df.iloc[train_size + test_size:]  # Conjunto de evaluación

    return df_train, df_test, df_eval


def scale_datasets(train_df, test_df, eval_df):

    scalers = {}  # Diccionario para almacenar los escaladores
    scaled_train_df = train_df.copy()  # Copia del DataFrame de entrenamiento
    scaled_test_df = test_df.copy()  # Copia del DataFrame de prueba
    scaled_eval_df = eval_df.copy()  # Copia del DataFrame de evaluación

    for column in train_df.columns:
        scaler = MinMaxScaler()  # Crear un escalador MinMax para cada columna
        scaled_train_df[column] = scaler.fit_transform(train_df[[column]])  # Ajustar y transformar los datos de entrenamiento
        scaled_test_df[column] = scaler.transform(test_df[[column]])  # Transformar los datos de prueba
        scaled_eval_df[column] = scaler.transform(eval_df[[column]])  # Transformar los datos de evaluación
        scalers[column] = scaler  # Guardar el escalador para cada columna

    return scaled_train_df, scaled_test_df, scaled_eval_df, scalers

def create_sequences(data, input_columns, output_columns, time_steps, future_steps=1):

    X, y = [], []  # Listas para almacenar las secuencias de entrada y salida
    data_array = data.values  # Convertir el DataFrame a un array numpy

    input_indices = data.columns.get_indexer(input_columns)  # Índices de las columnas de entrada
    output_indices = data.columns.get_indexer(output_columns)  # Índices de las columnas de salida

    for i in range(len(data) - time_steps - future_steps + 1):
        X.append(data_array[i:i + time_steps, input_indices])  # Crear secuencia de entrada
        y.append(data_array[i + time_steps:i + time_steps + future_steps, output_indices].flatten())  # Crear secuencia de salida

    return np.array(X), np.array(y)

def create_simple_rnn_model(input_shape, output_size, future_steps, rnn_units=50, hidden_units=50, output_activation='linear'):

    model = Sequential()  # Crear un modelo secuencial
    model.add(SimpleRNN(rnn_units, input_shape=input_shape, return_sequences=False))  # Añadir capa SimpleRNN
    model.add(Dense(hidden_units, activation='relu'))  # Añadir capa oculta densa
    model.add(Dense(output_size * future_steps, activation=output_activation))  # Añadir capa de salida
    model.compile(optimizer='adam', loss='mse', metrics=[rmse])  # Compilar el modelo
    return model

# %%
def plot_final_prediction(model, X, y, scalers, output_columns, future_steps, title):

    predictions = model.predict(X).reshape(-1, future_steps, len(output_columns))  # Realizar predicciones y darles forma

    # Reescalar las predicciones y los valores reales
    y_rescaled = np.zeros((y.shape[0], len(output_columns)))
    predictions_rescaled = np.zeros((predictions.shape[0], future_steps, len(output_columns)))

    for i, column in enumerate(output_columns):
        y_rescaled[:, i] = scalers[column].inverse_transform(y[:, i].reshape(-1, 1)).reshape(-1)  # Reescalar valores reales
        for step in range(future_steps):
            predictions_rescaled[:, step, i] = scalers[column].inverse_transform(predictions[:, step, i].reshape(-1, 1)).reshape(-1)  # Reescalar predicciones

    plt.figure(figsize=(14, 5))  # Crear figura
    for i in range(len(output_columns)):
        plt.plot(y_rescaled[:, i], label='Valor Real')  # Graficar valores reales
        plt.plot(predictions_rescaled[:, -1, i], label='Predicción')  # Graficar predicciones
        plt.title(f'{title} - Variable {output_columns[i]}')  # Añadir título
        plt.legend()

    plt.tight_layout()
    plt.show()

# Función para graficar los errores finales del modelo
def plot_final_errors(model, X, y, scalers, output_columns, future_steps, title):

    predictions = model.predict(X).reshape(-1, future_steps, len(output_columns))  # Realizar predicciones y darles forma

    # Reescalar las predicciones y los valores reales
    y_rescaled = np.zeros((y.shape[0], len(output_columns)))
    predictions_rescaled = np.zeros((predictions.shape[0], future_steps, len(output_columns)))

    for i, column in enumerate(output_columns):
        y_rescaled[:, i] = scalers[column].inverse_transform(y[:, i].reshape(-1, 1)).reshape(-1)  # Reescalar valores reales
        for step in range(future_steps):
            predictions_rescaled[:, step, i] = scalers[column].inverse_transform(predictions[:, step, i].reshape(-1, 1)).reshape(-1)  # Reescalar predicciones

    errors_rescaled = y_rescaled - predictions_rescaled[:, -1, :]  # Calcular errores reescalados

    plt.figure(figsize=(14, 5))  # Crear figura
    for i in range(len(output_columns)):
        plt.plot(errors_rescaled[:, i], label='Error')  # Graficar errores
        plt.title(f'{title} - Error Variable {output_columns[i]}')  # Añadir título
        plt.legend()

    plt.tight_layout()
    plt.show()

def plot_training_history(history, title='Historial de Entrenamiento'):

    # Extraer la información del historial
    history_dict = history.history

    # Crear una figura
    plt.figure(figsize=(14, 5))

    # Graficar la pérdida (loss)
    plt.subplot(1, 2, 1)
    plt.plot(history_dict['loss'], label='Pérdida en Entrenamiento')
    if 'val_loss' in history_dict:
        plt.plot(history_dict['val_loss'], label='Pérdida en Validación')
    plt.xlabel('Épocas')
    plt.ylabel('Pérdida')
    plt.title('Pérdida durante el Entrenamiento')
    plt.legend()

    # Graficar la métrica RMSE
    plt.subplot(1, 2, 2)
    plt.plot(history_dict['rmse'], label='RMSE en Entrenamiento')
    if 'val_rmse' in history_dict:
        plt.plot(history_dict['val_rmse'], label='RMSE en Validación')
    plt.xlabel('Épocas')
    plt.ylabel('RMSE')
    plt.title('RMSE durante el Entrenamiento')
    plt.legend()

    # Ajustar el diseño y mostrar la gráfica
    plt.suptitle(title)
    plt.tight_layout()
    plt.show()

# %%
# Paso 1: Leer el archivo CSV
file_path = 'Agentes_contaminantes_corregido.csv'  # Reemplaza con la ruta a tu archivo
df = pd.read_csv(file_path)

df_train, df_test, df_eval = split_dataframe(df, train_ratio=0.7, test_ratio=0.2)

print(f"Tamaño de datos de entrenamiento: {len(df_train)}")
print(f"Tamaño de datos de prueba: {len(df_test)}")
print(f"Tamaño de datos de evaluación: {len(df_eval)}")
# Out:
# Tamaño de datos de entrenamiento: 2151
# Tamaño de datos de prueba: 614
# Tamaño de datos de evaluación: 308

# %%
scaled_train_df, scaled_test_df, scaled_eval_df, scalers = scale_datasets(df_train, df_test, df_eval)

time_steps = 40
future_steps = 7
#input_columns = ['CE-CO','CE-PM10','julian_day','hour']  # Nombres de las columnas de entrada en el DataFrame escalado
input_columns = ['CO']  # Nombres de las columnas de entrada en el DataFrame escalado
output_columns = ['CO']  # Nombres de las columnas de salida en el DataFrame escalado


X_train, y_train = create_sequences(scaled_train_df, input_columns, output_columns, time_steps, future_steps)
X_test, y_test = create_sequences(scaled_test_df, input_columns, output_columns, time_steps, future_steps)
X_eval, y_eval = create_sequences(scaled_eval_df, input_columns, output_columns, time_steps, future_steps)

print(f"Tamaño de X_train: {X_train.shape}")
print(f"Tamaño de y_train: {y_train.shape}")
print(f"Tamaño de X_test: {X_test.shape}")
print(f"Tamaño de y_test: {y_test.shape}")
print(f"Tamaño de X_eval: {X_eval.shape}")
print(f"Tamaño de y_eval: {y_eval.shape}")

input_shape = (X_train.shape[1], X_train.shape[2])
output_size = len(output_columns)
# Out:
# Tamaño de X_train: (2105, 40, 1)
# Tamaño de y_train: (2105, 7)
# Tamaño de X_test: (568, 40, 1)
# Tamaño de y_test: (568, 7)
# Tamaño de X_eval: (262, 40, 1)
# Tamaño de y_eval: (262, 7)

# %%
# Crear y entrenar el modelo SimpleRNN
model_simple_rnn = create_simple_rnn_model(input_shape, output_size, future_steps)
history_simple_rnn = model_simple_rnn.fit(X_train, y_train, epochs=75, batch_size=128, validation_data=(X_test, y_test), shuffle=True)
plot_training_history(history_simple_rnn)
# Out:
# Epoch 1/75
# 17/17 [==============================] - 3s 84ms/step - loss: 0.1162 - rmse: 0.3272 - val_loss: 0.0222 - val_rmse: 0.1435
# Epoch 2/75
# 17/17 [==============================] - 0s 27ms/step - loss: 0.0300 - rmse: 0.1710 - val_loss: 0.0146 - val_rmse: 0.1173
# Epoch 3/75
# 17/17 [==============================] - 0s 19ms/step - loss: 0.0194 - rmse: 0.1391 - val_loss: 0.0132 - val_rmse: 0.1106
# Epoch 4/75
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0182 - rmse: 0.1349 - val_loss: 0.0122 - val_rmse: 0.1064
# Epoch 5/75
# 17/17 [==============================] - 0s 21ms/step - loss: 0.0178 - rmse: 0.1333 - val_loss: 0.0117 - val_rmse: 0.1041
# Epoch 6/75
# 17/17 [==============================] - 0s 18ms/step - loss: 0.0172 - rmse: 0.1311 - val_loss: 0.0120 - val_rmse: 0.1051
# Epoch 7/75
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0172 - rmse: 0.1316 - val_loss: 0.0108 - val_rmse: 0.0994
# Epoch 8/75
# 17/17 [==============================] - 0s 20ms/step - loss: 0.0171 - rmse: 0.1306 - val_loss: 0.0121 - val_rmse: 0.1057
# Epoch 9/75
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0171 - rmse: 0.1309 - val_loss: 0.0114 - val_rmse: 0.1023
# Epoch 10/75
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0166 - rmse: 0.1286 - val_loss: 0.0106 - val_rmse: 0.0981
# Epoch 11/75
# 17/17 [==============================] - 0s 18ms/step - loss: 0.0164 - rmse: 0.1275 - val_loss: 0.0106 - val_rmse: 0.0980
# Epoch 12/75
# 17/17 [==============================] - 0s 19ms/step - loss: 0.0163 - rmse: 0.1273 - val_loss: 0.0105 - val_rmse: 0.0976
# Epoch 13/75
# 17/17 [==============================] - 0s 15ms/step - loss: 0.
75
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0155 - rmse: 0.1249 - val_loss: 0.0104 - val_rmse: 0.0981
# Epoch 75/75
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0153 - rmse: 0.1235 - val_loss: 0.0099 - val_rmse: 0.0947

# %%
# Evaluar los modelos en el conjunto de evaluación
loss_simple_rnn, rmse_simple_rnn = model_simple_rnn.evaluate(X_eval, y_eval)
print(f"SimpleRNN - Loss en el conjunto de evaluación: {loss_simple_rnn}")
print(f"SimpleRNN - RMSE en el conjunto de evaluación: {rmse_simple_rnn}")
# Out:
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0131 - rmse: 0.1140
# SimpleRNN - Loss en el conjunto de evaluación: 0.013111105188727379
# SimpleRNN - RMSE en el conjunto de evaluación: 0.1139950230717659

# %%
plot_final_prediction(model_simple_rnn, X_eval, y_eval, scalers, output_columns, future_steps, title='SimpleRNN - Predicción Final')
plot_final_errors(model_simple_rnn, X_eval, y_eval, scalers, output_columns, future_steps, title='SimpleRNN - Error Final')
# Out:
# 9/9 [==============================] - 0s 4ms/step
# 9/9 [==============================] - 0s 12ms/step

# %%
def add_predictions(model, data, input_columns, output_columns, time_steps, future_steps):

    # Escaladores
    scalers = {col: MinMaxScaler() for col in data.columns}

    # Escalar datos
    scaled_data = data.copy()
    for col in data.columns:
        scaled_data[col] = scalers[col].fit_transform(data[[col]])

    # Seleccionar la última secuencia de time_steps
    last_seq = scaled_data[input_columns].values[-time_steps:]
    last_seq = np.expand_dims(last_seq, axis=0)

    # Realizar la predicción
    predictions_scaled = model.predict(last_seq)

    # Reescalar las predicciones
    predictions = np.zeros((future_steps, len(output_columns)))
    for i, col in enumerate(output_columns):
        predictions[:, i] = scalers[col].inverse_transform(predictions_scaled[:, i::len(output_columns)].reshape(-1, 1)).reshape(-1)

    # Crear un DataFrame para las predicciones
    predictions_df = pd.DataFrame(predictions, columns=output_columns)

    # Añadir las predicciones al DataFrame original
    data_with_predictions = pd.concat([data, predictions_df], ignore_index=True)

    return data_with_predictions

def plot_with_predictions(data, output_columns, plot_steps, future_steps):

    plt.figure(figsize=(14, 5))
    for col in output_columns:
        plt.plot(data.index[-(plot_steps + future_steps):], data[col].iloc[-(plot_steps + future_steps):], label=f'Actual {col}')
        plt.plot(data.index[-future_steps:], data[col].iloc[-future_steps:], 'ro-', label=f'Predicción {col}')

    plt.title('Predicciones y datos actuales')
    plt.legend()
    plt.show()
plot_steps = 12  # Número de pasos de tiempo a graficar antes de la predicción

# Añadir predicciones y visualizar
df_with_predictions = add_predictions(model_simple_rnn, df, input_columns, output_columns, time_steps, future_steps)
plot_with_predictions(df_with_predictions, output_columns, plot_steps, future_steps)
# Out:
# 1/1 [==============================] - 0s 118ms/step

# %%
scaled_train_df, scaled_test_df, scaled_eval_df, scalers = scale_datasets(df_train, df_test, df_eval)

time_steps = 40
future_steps = 7
#input_columns = ['CE-CO','CE-PM10','julian_day','hour']  # Nombres de las columnas de entrada en el DataFrame escalado
input_columns = ['CO', 'NOX', 'SO2']  # Nombres de las columnas de entrada en el DataFrame escalado
output_columns = ['CO', 'NOX', 'SO2']  # Nombres de las columnas de salida en el DataFrame escalado


X_train, y_train = create_sequences(scaled_train_df, input_columns, output_columns, time_steps, future_steps)
X_test, y_test = create_sequences(scaled_test_df, input_columns, output_columns, time_steps, future_steps)
X_eval, y_eval = create_sequences(scaled_eval_df, input_columns, output_columns, time_steps, future_steps)

print(f"Tamaño de X_train: {X_train.shape}")
print(f"Tamaño de y_train: {y_train.shape}")
print(f"Tamaño de X_test: {X_test.shape}")
print(f"Tamaño de y_test: {y_test.shape}")
print(f"Tamaño de X_eval: {X_eval.shape}")
print(f"Tamaño de y_eval: {y_eval.shape}")

input_shape = (X_train.shape[1], X_train.shape[2])
output_size = len(output_columns)
# Out:
# Tamaño de X_train: (2105, 40, 3)
# Tamaño de y_train: (2105, 21)
# Tamaño de X_test: (568, 40, 3)
# Tamaño de y_test: (568, 21)
# Tamaño de X_eval: (262, 40, 3)
# Tamaño de y_eval: (262, 21)

# %%
# Crear y entrenar el modelo SimpleRNN
model_simple_rnn = create_simple_rnn_model(input_shape, output_size, future_steps)
history_simple_rnn = model_simple_rnn.fit(X_train, y_train, epochs=75, batch_size=128, validation_data=(X_test, y_test), shuffle=True)
plot_training_history(history_simple_rnn)
# Out:
# Epoch 1/75
# 17/17 [==============================] - 4s 35ms/step - loss: 0.1438 - rmse: 0.3717 - val_loss: 0.0514 - val_rmse: 0.2180
# Epoch 2/75
# 17/17 [==============================] - 0s 18ms/step - loss: 0.0603 - rmse: 0.2427 - val_loss: 0.0281 - val_rmse: 0.1613
# Epoch 3/75
# 17/17 [==============================] - 0s 17ms/step - loss: 0.0360 - rmse: 0.1891 - val_loss: 0.0232 - val_rmse: 0.1462
# Epoch 4/75
# 17/17 [==============================] - 0s 19ms/step - loss: 0.0322 - rmse: 0.1794 - val_loss: 0.0215 - val_rmse: 0.1400
# Epoch 5/75
# 17/17 [==============================] - 0s 19ms/step - loss: 0.0310 - rmse: 0.1757 - val_loss: 0.0207 - val_rmse: 0.1368
# Epoch 6/75
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0302 - rmse: 0.1736 - val_loss: 0.0209 - val_rmse: 0.1374
# Epoch 7/75
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0296 - rmse: 0.1722 - val_loss: 0.0199 - val_rmse: 0.1337
# Epoch 8/75
# 17/17 [==============================] - 0s 17ms/step - loss: 0.0295 - rmse: 0.1716 - val_loss: 0.0195 - val_rmse: 0.1324
# Epoch 9/75
# 17/17 [==============================] - 0s 19ms/step - loss: 0.0290 - rmse: 0.1704 - val_loss: 0.0199 - val_rmse: 0.1340
# Epoch 10/75
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0285 - rmse: 0.1689 - val_loss: 0.0197 - val_rmse: 0.1332
# Epoch 11/75
# 17/17 [==============================] - 0s 18ms/step - loss: 0.0280 - rmse: 0.1673 - val_loss: 0.0190 - val_rmse: 0.1307
# Epoch 12/75
# 17/17 [==============================] - 0s 17ms/step - loss: 0.0277 - rmse: 0.1664 - val_loss: 0.0187 - val_rmse: 0.1293
# Epoch 13/75
# 17/17 [==============================] - 0s 17ms/step - loss: 0.0274 - rmse: 0.1655 - val_loss: 0.0185 - val_rmse: 0.1286
# Epoch 14/75
# 17/17 [==============================] - 0s 18ms/step - loss: 0.0272 - rmse: 0.1652 - val_loss: 0.0187 - val_rmse: 0.1292
# Epoch 15/75
# 17/17 [==============================] - 0s 18ms/step - loss: 0.0271 - rmse: 0.1648 - val_loss: 0.0187 - val_rmse: 0.1289
# Epoch 16/75
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0271 - rmse: 0.1647 - val_loss: 0.0184 - val_rmse: 0.1280
# Epoch 17/75
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0269 - rmse: 0.1640 - val_loss: 0.0184 - val_rmse: 0.1280
# Epoch 18/75
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0270 - rmse: 0.1645 - val_loss: 0.0209 - val_rmse: 0.1387
# Epoch 19/75
# 17/17 [==============================] - 0s 18ms/step - loss: 0.0276 - rmse: 0.1662 - val_loss: 0.0187 - val_rmse: 0.1290
# Epoch 20/75
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0270 - rmse: 0.1639 - val_loss: 0.0184 - val_rmse: 0.1282
# Epoch 21/75
# 17/17 [==============================] - 0s 15ms/step - loss: 0.
75
# 17/17 [==============================] - 0s 17ms/step - loss: 0.0254 - rmse: 0.1591 - val_loss: 0.0181 - val_rmse: 0.1275
# Epoch 52/75
# 17/17 [==============================] - 0s 19ms/step - loss: 0.0253 - rmse: 0.1587 - val_loss: 0.0178 - val_rmse: 0.1265
# Epoch 53/75
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0253 - rmse: 0.1592 - val_loss: 0.0178 - val_rmse: 0.1262
# Epoch 54/75
# 17/17 [==============================] - 0s 18ms/step - loss: 0.0252 - rmse: 0.1589 - val_loss: 0.0179 - val_rmse: 0.1263
# Epoch 55/75
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0252 - rmse: 0.1591 - val_loss: 0.0180 - val_rmse: 0.1272
# Epoch 56/75
# 17/17 [==============================] - 0s 17ms/step - loss: 0.0253 - rmse: 0.1591 - val_loss: 0.0182 - val_rmse: 0.1276
# Epoch 57/75
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0253 - rmse: 0.1588 - val_loss: 0.0178 - val_rmse: 0.1260
# Epoch 58/75
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0251 - rmse: 0.1581 - val_loss: 0.0177 - val_rmse: 0.1257
# Epoch 59/75
# 17/17 [==============================] - 0s 18ms/step - loss: 0.0251 - rmse: 0.1583 - val_loss: 0.0179 - val_rmse: 0.1260
# Epoch 60/75
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0250 - rmse: 0.1585 - val_loss: 0.0180 - val_rmse: 0.1262
# Epoch 61/75
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0250 - rmse: 0.1578 - val_loss: 0.0179 - val_rmse: 0.1264
# Epoch 62/75
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0250 - rmse: 0.1582 - val_loss: 0.0181 - val_rmse: 0.1265
# Epoch 63/75
# 17/17 [==============================] - 0s 19ms/step - loss: 0.0252 - rmse: 0.1588 - val_loss: 0.0177 - val_rmse: 0.1256
# Epoch 64/75
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0250 - rmse: 0.1583 - val_loss: 0.0178 - val_rmse: 0.1258
# Epoch 65/75
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0250 - rmse: 0.1577 - val_loss: 0.0178 - val_rmse: 0.1260
# Epoch 66/75
# 17/17 [==============================] - 0s 17ms/step - loss: 0.0250 - rmse: 0.1581 - val_loss: 0.0182 - val_rmse: 0.1272
# Epoch 67/75
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0249 - rmse: 0.1578 - val_loss: 0.0181 - val_rmse: 0.1269
# Epoch 68/75
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0249 - rmse: 0.1577 - val_loss: 0.0179 - val_rmse: 0.1263
# Epoch 69/75
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0248 - rmse: 0.1578 - val_loss: 0.0181 - val_rmse: 0.1277
# Epoch 70/75
# 17/17 [==============================] - 0s 18ms/step - loss: 0.0249 - rmse: 0.1572 - val_loss: 0.0178 - val_rmse: 0.1262
# Epoch 71/75
# 17/17 [==============================] - 0s 17ms/step - loss: 0.0248 - rmse: 0.1575 - val_loss: 0.0179 - val_rmse: 0.1262
# Epoch 72/75
# 17/17 [==============================] - 0s 17ms/step - loss: 0.0248 - rmse: 0.1576 - val_loss: 0.0180 - val_rmse: 0.1264
# Epoch 73/75
# 17/17 [==============================] - 0s 19ms/step - loss: 0.0248 - rmse: 0.1576 - val_loss: 0.0178 - val_rmse: 0.1257
# Epoch 74/75
# 17/17 [==============================] - 0s 27ms/step - loss: 0.0247 - rmse: 0.1568 - val_loss: 0.0180 - val_rmse: 0.1265
# Epoch 75/75
# 17/17 [==============================] - 0s 28ms/step - loss: 0.0247 - rmse: 0.1565 - val_loss: 0.0178 - val_rmse: 0.1256

# %%
# Evaluar los modelos en el conjunto de evaluación
loss_simple_rnn, rmse_simple_rnn = model_simple_rnn.evaluate(X_eval, y_eval)
print(f"SimpleRNN - Loss en el conjunto de evaluación: {loss_simple_rnn}")
print(f"SimpleRNN - RMSE en el conjunto de evaluación: {rmse_simple_rnn}")
# Out:
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0175 - rmse: 0.1308
# SimpleRNN - Loss en el conjunto de evaluación: 0.017526857554912567
# SimpleRNN - RMSE en el conjunto de evaluación: 0.13084706664085388

# %%
plot_final_prediction(model_simple_rnn, X_eval, y_eval, scalers, output_columns, future_steps, title='SimpleRNN - Predicción Final')
plot_final_errors(model_simple_rnn, X_eval, y_eval, scalers, output_columns, future_steps, title='SimpleRNN - Error Final')
# Out:
# 9/9 [==============================] - 0s 6ms/step
# 9/9 [==============================] - 0s 4ms/step

# %%
def add_predictions(model, data, input_columns, output_columns, time_steps, future_steps):

    # Escaladores
    scalers = {col: MinMaxScaler() for col in data.columns}

    # Escalar datos
    scaled_data = data.copy()
    for col in data.columns:
        scaled_data[col] = scalers[col].fit_transform(data[[col]])

    # Seleccionar la última secuencia de time_steps
    last_seq = scaled_data[input_columns].values[-time_steps:]
    last_seq = np.expand_dims(last_seq, axis=0)

    # Realizar la predicción
    predictions_scaled = model.predict(last_seq)

    # Reescalar las predicciones
    predictions = np.zeros((future_steps, len(output_columns)))
    for i, col in enumerate(output_columns):
        predictions[:, i] = scalers[col].inverse_transform(predictions_scaled[:, i::len(output_columns)].reshape(-1, 1)).reshape(-1)

    # Crear un DataFrame para las predicciones
    predictions_df = pd.DataFrame(predictions, columns=output_columns)

    # Añadir las predicciones al DataFrame original
    data_with_predictions = pd.concat([data, predictions_df], ignore_index=True)

    return data_with_predictions

def plot_with_predictions(data, output_columns, plot_steps, future_steps):

    plt.figure(figsize=(14, 5))
    for col in output_columns:
        plt.plot(data.index[-(plot_steps + future_steps):], data[col].iloc[-(plot_steps + future_steps):], label=f'Actual {col}')
        plt.plot(data.index[-future_steps:], data[col].iloc[-future_steps:], 'ro-', label=f'Predicción {col}')

    plt.title('Predicciones y datos actuales')
    plt.legend()
    plt.show()
plot_steps = 12  # Número de pasos de tiempo a graficar antes de la predicción

# Añadir predicciones y visualizar
df_with_predictions = add_predictions(model_simple_rnn, df, input_columns, output_columns, time_steps, future_steps)
plot_with_predictions(df_with_predictions, output_columns, plot_steps, future_steps)
# Out:
# 1/1 [==============================] - 0s 23ms/step

# %%
model_simple_rnn.save('Modelo_simple')


import joblib
import os

def save_scalers(scalers, directory):

    # Crear el directorio si no existe
    os.makedirs(directory, exist_ok=True)

    # Guardar cada escalador en un archivo separado
    for column, scaler in scalers.items():
        file_path = os.path.join(directory, f'{column}_scaler.pkl')
        joblib.dump(scaler, file_path)
        print(f"Escalador para {column} guardado en {file_path}")


save_scalers(scalers, 'scalers')
# Out:
# Escalador para CO guardado en scalers/CO_scaler.pkl
# Escalador para NO guardado en scalers/NO_scaler.pkl
# Escalador para NO2 guardado en scalers/NO2_scaler.pkl
# Escalador para NOX guardado en scalers/NOX_scaler.pkl
# Escalador para O3 guardado en scalers/O3_scaler.pkl
# Escalador para PM10 guardado en scalers/PM10_scaler.pkl
# Escalador para PM25 guardado en scalers/PM25_scaler.pkl
# Escalador para SO2 guardado en scalers/SO2_scaler.pkl

# %% [markdown]
# Conclusiones
#
#
# *   Con 75 epocas se ven bien las predicciones del modelo.
# *   La tendencia de las distintas variables (CO, NOX, SO2) se ve estacionaria.
# *   El CO y SO2 presenta más ruido que el NOX, el NOX presenta poco ruido.
# *   Para el NOX parace que si tiene estacionalidad, el CO y SO2 no parecen tener estacionalidad.
